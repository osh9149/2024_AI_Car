# %% [markdown]
# <a href="https://colab.research.google.com/github/osh9149/2024_AI_Car/blob/main/aicarA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <STEP 1>이미지 파일 압축 풀기 - 실행 하기 전 압축파일(*.zip)을 올려 놓아야 합니다.

# %%
epochN = None; learnRate = None                                                 # epochN = 300, learnRate = 0.0005/0.0010/0.0015/0.0020/0.0025
import glob
import zipfile
fileList = glob.glob('*.zip')
zip_ref = zipfile.ZipFile(fileList[0], 'r');
zip_ref.extractall()
zip_ref.close()
w = fileList[0].split('.'); project = w[-2]
print(project)
# Out:
# img2

# %% [markdown]
# <STEP 2> 라이브러리 가져오기(Import)

# %%
import os
import sys
import random
import fnmatch
import pickle
import time
import numpy as np
import cv2 as cv                                 # Open Cv 영상처리 라이브러리
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
from torchsummary import summary as summary
import torch.nn.functional as F
import torch.optim as optim
from sklearn.metrics import mean_squared_error, r2_score
# %matplotlib inline
from PIL import Image

print(f'Python Version:     {sys.version}')                                     # Python Version
print(f'OpenCV version:     {cv.__version__}')                                  # Open CV version
print(f'Pytorch version:    {torch.__version__}')                               # Pytorch version
# Out:
# Python Version:     3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# OpenCV version:     4.8.0
# Pytorch version:    2.1.0+cu121

# %% [markdown]
# <STEP 3> 이미지 데이터 조향각 추출

# %%
#dataDir = '/content/'+project                                                   # colab 내부 프로젝트 디렉터리
with open(f'{project}/_{project}.pickle', 'rb') as f:                           # pickle 파일
    x_exam_Image = pickle.load(f)                                               # 시험(Test) 이미지 파일 이름 리스트
    x_valid_Image = pickle.load(f)                                              # 평가(Valid) 이미지 파일 이름 리스트
    x_train_Image = pickle.load(f)                                              # 훈련(Train) 이미지 파일 이름 리스트
    p = pickle.load(f)                                                          # 파라메터 리스트
if epochN == None:    epochN =    p[0]                                          # 학습회수
if learnRate == None: learnRate = p[1]                                          # 학습 비율 0.0005/0.0010/0.0015/0.0020/0.0025
#-------------------------------------------------------------------------------
y_exam_Angle=[]
y_valid_Angle=[]
y_train_Angle = []
for f in x_exam_Image:                   # 시험용 이미지 파일 이름에서 각도값
    y_exam_Angle.append(int(f[-7:-4]))
for f in x_valid_Image:                  # 평가용 이미지 파일 이름에서 각도값
    y_valid_Angle.append(int(f[-7:-4]))
for f in x_train_Image:                  # 훈련용 이미지 파일 이름에서 각도값
    y_train_Angle.append(int(f[-7:-4]))

# %% [markdown]
# <STEP 4> Nvidia CNN 모델 구성, 딥러닝

# %%
# Pytorch device 설정
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(f'{device} is available')

# Nvidia CNN 모델 구성 ---------------------------------------------------------
class NvidiaModel(nn.Module):
    def __init__(self):
      super(NvidiaModel, self).__init__()

      # elu=Expenential Linear Unit, similar to leaky Relu
      # skipping 1st hiddel layer (nomralization layer), as we have normalized the data

      # Convolution Layers
      self.layer1 = nn.Sequential(
        nn.Conv2d(in_channels=3, out_channels=24, kernel_size=(5, 5), stride=(2, 2)),
        nn.ELU(inplace=True),
        nn.Conv2d(in_channels=24, out_channels=36, kernel_size=(5, 5), stride=(2, 2)),
        nn.ELU(inplace=True),
        nn.Conv2d(in_channels=36, out_channels=48, kernel_size=(5, 5), stride=(2, 2)),
        nn.ELU(inplace=True),
        nn.Conv2d(in_channels=48, out_channels=64, kernel_size=(3, 3)),
        nn.ELU(inplace=True),
        nn.Dropout(0.2),
        nn.Conv2d(in_channels=64, out_channels=64, kernel_size=(3, 3)),
        nn.ELU(inplace=True)
      )

      # Fully Connected Layers
      self.layer2 = nn.Sequential(
        # nn.Flatten(),
        nn.Dropout(0.2),
        nn.Linear(in_features=18 * 64, out_features=100),
        nn.ELU(inplace=True),
        nn.Linear(in_features=100, out_features=50),
        nn.ELU(inplace=True),
        nn.Linear(in_features=50, out_features=10),
        nn.ELU(inplace=True)
      )

      # Output Layer
      self.layer3 = nn.Sequential(
        nn.Linear(in_features=10, out_features=1)
      )

    def forward(self, x):
      x = self.layer1(x)
      x = x.view(x.shape[0], -1)
      x = self.layer2(x)
      x = self.layer3(x)

      return x


#-------------------------------------------------------------------------------
def imgPaths(fGroup):
    r = []
    for filename in fGroup:
        r.append(os.path.join(project, filename))                               # 파일 경로(path)를 화일 이름 앞에 부착하여 리스트에 추가
    return(r)

# 학습 데이터 생성 -------------------------------------------------------------
class CustomDataset(Dataset):
    def __init__(self, imageList, angleList):
        self.imageList = imgPaths(imageList)
        self.angleList = angleList

        for i in range(len(imageList)):
            image = cv.imread(self.imageList[i])
            image = image / 255
            self.imageList[i] = image

    def __len__(self):
        return len(self.imageList)

    def __getitem__(self, index):
        images = torch.FloatTensor(self.imageList[index]).permute(2,0,1)
        angles = torch.FloatTensor([self.angleList[index]])
        return images, angles
#-------------------------------------------------------------------------------
class EarlyStopping:
    """주어진 patience 이후로 validation loss가 개선되지 않으면 학습을 조기 중지"""
    def __init__(self, patience=7, verbose=False, delta=0, path=f'_{project}_model_check.pt'):
        """
            patience (int): validation loss가 개선된 후 기다리는 기간               - Default: 7
            verbose (bool): True일 경우 각 validation loss의 개선 사항 메세지 출력  - Default: False
            delta (float): 개선되었다고 인정되는 monitered quantity의 최소 변화     - Default: 0
            path (str): checkpoint저장 경로
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path

    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f'Early Stopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''validation loss가 감소하면 모델을 저장한다.'''
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), self.path)
        # torch.save(model, self.path)
        self.val_loss_min = val_loss

# 모델 학습 --------------------------------------------------------------------
def learnProc():
  model = NvidiaModel().to(device)

  train_dataset = CustomDataset(x_train_Image, y_train_Angle)
  train_loader = DataLoader(train_dataset, batch_size=len(x_train_Image))

  valid_dataset = CustomDataset(x_valid_Image, y_valid_Angle)
  valid_loader = DataLoader(valid_dataset, batch_size=len(x_valid_Image))

  optimizer = optim.Adam(model.parameters(), lr=learnRate)
  criterion = nn.MSELoss().to(device)

  early_stopping = EarlyStopping(patience=30, verbose=True)

  EPOCHS = 300
  train_losses = []
  valid_losses = []
  avg_train_losses = []
  avg_valid_losses = []
  for epoch in range(1, EPOCHS + 1):
      # 학습
      model.train()

      for batch_idx, (data, target) in enumerate(train_loader):
          data, target = data.to(device), target.to(device)
          optimizer.zero_grad()

          output = model(data)

          loss = criterion(output.to(torch.float32), target.to(torch.float32))
          loss.backward()
          optimizer.step()

          train_losses.append(loss.item())

      # 검증
      model.eval()

      with torch.no_grad():
        for data, target in valid_loader:
            data, target = data.to(device), target.to(device)

            output = model(data)

            loss = criterion(output.to(torch.float32), target.to(torch.float32))

            valid_losses.append(loss.item())

      train_loss = np.average(train_losses)
      valid_loss = np.average(valid_losses)
      avg_train_losses.append(train_loss)
      avg_valid_losses.append(valid_loss)

      epoch_len = len(str(EPOCHS))

      print_msg = (f'[{epoch:>{epoch_len}}/{EPOCHS:>{epoch_len}}] ' +
                      f'train_loss: {train_loss:.6f} ' +
                      f'valid_loss: {valid_loss:.6f}')

      print(print_msg)

      train_losses = []
      valid_losses = []

      early_stopping(valid_loss, model)

      if early_stopping.early_stop:
          print("Early stopping")
          break

  return {'loss':avg_train_losses, 'val_loss':avg_valid_losses}

# 학습 시작---------------------------------------------------------------------
print()
print('시험 이미지 개수:',len(x_exam_Image))
print('평가 이미지 개수:',len(x_valid_Image))
print('훈련 이미지 개수:',len(x_train_Image))
print('학습 비율=', learnRate)
print('학습 회수=', epochN)
print()
startTime = time.time()                                                         # 학습 시작 시간 저장
history = learnProc()                                                           # 학습 시작
elapsedTime = int(time.time() - startTime)                                      # 학습 경과 시간 저장
lossMin = min(history['loss'])                                                  # 딕셔너리 history의 'loss'키 데이터는 리스트, 최소값
val_lossMin = min(history['val_loss'])                                          # 딕셔너리 history의 'val_loss'키 데이터는 리스트, 최소값
#-------------------------------------------------------------------------------
plt.plot(history['loss'],color='blue')
plt.plot(history['val_loss'],color='red')
plt.legend([f'training loss Min: {lossMin:0.2f}', f'validation loss Min: {val_lossMin:0.2f}'])
plt.savefig(f'_{project}_result.png')                                           # plot 이미지 저장
# Out:
# cuda:0 is available
#
# 시험 이미지 개수: 6
# 평가 이미지 개수: 72
# 훈련 이미지 개수: 296
# 학습 비율= 0.001
# 학습 회수= 300
#
# [  1/300] train_loss: 996.250549 valid_loss: 1061.543579
# Validation loss decreased (inf --> 1061.543579).  Saving model ...
# [  2/300] train_loss: 996.169556 valid_loss: 1061.172852
# Validation loss decreased (1061.543579 --> 1061.172852).  Saving model ...
# [  3/300] train_loss: 995.805054 valid_loss: 1059.372070
# Validation loss decreased (1061.172852 --> 1059.372070).  Saving model ...
# [  4/300] train_loss: 994.033264 valid_loss: 1053.631470
# Validation loss decreased (1059.372070 --> 1053.631470).  Saving model ...
# [  5/300] train_loss: 988.724060 valid_loss: 1042.155151
# Validation loss decreased (1053.631470 --> 1042.155151).  Saving model ...
# [  6/300] train_loss: 978.310608 valid_loss: 1026.009766
# Validation loss decreased (1042.155151 --> 1026.009766).  Saving model ...
# [  7/300] train_loss: 965.119873 valid_loss: 1006.708008
# Validation loss decreased (1026.009766 --> 1006.708008).  Saving model ...
# [  8/300] train_loss: 946.518188 valid_loss: 978.857300
# Validation loss decreased (1006.708008 --> 978.857300).  Saving model ...
# [  9/300] train_loss: 920.980713 valid_loss: 946.822083
# Validation loss decreased (978.857300 --> 946.822083).  Saving model ...
# [ 10/300] train_loss: 890.440247 valid_loss: 897.980164
# Validation loss decreased (946.822083 --> 897.980164).  Saving model ...
# [ 11/300] train_loss: 846.694519 valid_loss: 838.027039
# Validation loss decreased (897.980164 --> 838.027039).  Saving model ...
# [ 12/300] train_loss: 791.295410 valid_loss: 805.642029
# Validation loss decreased (838.027039 --> 805.642029).  Saving model ...
# [ 13/300] train_loss: 747.893066 valid_loss: 771.477112
# Validation loss decreased (805.642029 --> 771.477112).  Saving model ...
# [ 14/300] train_loss: 734.770691 valid_loss: 731.439270
# Validation loss decreased (771.477112 --> 731.439270).  Saving model ...
# [ 15/300] train_loss: 710.059326 valid_loss: 636.628296
# Validation loss decreased (731.439270 --> 636.628296).  Saving model ...
# [ 16/300] train_loss: 647.536743 valid_loss: 545.432007
# Validation loss decreased (636.628296 --> 545.432007).  Saving model ...
# [ 17/300] train_loss: 589.204224 valid_loss: 492.429413
# Validation loss decreased (545.432007 --> 492.429413).  Saving model ...
# [ 18/300] train_loss: 550.986633 valid_loss: 457.363922
# Validation loss decreased (492.429413 --> 457.363922).  Saving model ...
# [ 19/300] train_loss: 523.032471 valid_loss: 436.093964
# Validation loss decreased (457.363922 --> 436.093964).  Saving model ...
# [ 20/300] train_loss: 474.167297 valid_loss: 468.997559
# Early Stopping counter: 1 out of 30
# [ 21/300] train_loss: 480.005981 valid_loss: 374.476562
# Validation loss decreased (436.093964 --> 374.476562).  Saving model ...
# [ 22/300] train_loss: 413.965942 valid_loss: 358.338593
# Validation loss decreased (374.476562 --> 358.338593).  Saving model ...
# [ 23/300] train_loss: 408.974182 valid_loss: 354.314819
# Validation loss decreased (358.338593 --> 354.314819).  Saving model ...
# [ 24/300] train_loss: 420.833191 valid_loss: 339.374298
# Validation loss decreased (354.314819 --> 339.374298).  Saving model ...
# [ 25/300] train_loss: 406.989410 valid_loss: 329.469025
# Validation loss decreased (339.374298 --> 329.469025).  Saving model ...
# [ 26/300] train_loss: 375.094788 valid_loss: 333.764282
# Early Stopping counter: 1 out of 30
# [ 27/300] train_loss: 369.118805 valid_loss: 352.820465
# Early Stopping counter: 2 out of 30
# [ 28/300] train_loss: 366.385956 valid_loss: 340.801300
# Early Stopping counter: 3 out of 30
# [ 29/300] train_loss: 354.671082 valid_loss: 319.435211
# Validation loss decreased (329.469025 --> 319.435211).  Saving model ...
# [ 30/300] train_loss: 338.726898 valid_loss: 313.563110
# Validation loss decreased (319.435211 --> 313.563110).  Saving model ...
# [ 31/300] train_loss: 334.448639 valid_loss: 315.537415
# Early Stopping counter: 1 out of 30
# [ 32/300] train_loss: 321.808197 valid_loss: 303.050293
# Validation loss decreased (313.563110 --> 303.050293).  Saving model ...
# [ 33/300] train_loss: 295.600037 valid_loss: 291.976074
# Validation loss decreased (303.050293 --> 291.976074).  Saving model ...
# [ 34/300] train_loss: 310.521271 valid_loss: 285.417389
# Validation loss decreased (291.976074 --> 285.417389).  Saving model ...
# [ 35/300] train_loss: 304.346832 valid_loss: 277.739380
# Validation loss decreased (285.417389 --> 277.739380).  Saving model ...
# [ 36/300] train_loss: 298.673615 valid_loss: 284.979340
# Early Stopping counter: 1 out of 30
# [ 37/300] train_loss: 272.077362 valid_loss: 282.125336
# Early Stopping counter: 2 out of 30
# [ 38/300] train_loss: 281.212250 valid_loss: 263.836060
# Validation loss decreased (277.739380 --> 263.836060).  Saving model ...
# [ 39/300] train_loss: 252.791122 valid_loss: 251.928879
# Validation loss decreased (263.836060 --> 251.928879).  Saving model ...
# [ 40/300] train_loss: 230.514465 valid_loss: 247.883011
# Validation loss decreased (251.928879 --> 247.883011).  Saving model ...
# [ 41/300] train_loss: 246.970795 valid_loss: 254.264969
# Early Stopping counter: 1 out of 30
# [ 42/300] train_loss: 230.977280 valid_loss: 252.722733
# Early Stopping counter: 2 out of 30
# [ 43/300] train_loss: 230.729843 valid_loss: 236.315735
# Validation loss decreased (247.883011 --> 236.315735).  Saving model ...
# [ 44/300] train_loss: 217.513809 valid_loss: 223.477402
# Validation loss decreased (236.315735 --> 223.477402).  Saving model ...
# [ 45/300] train_loss: 220.043793 valid_loss: 217.400024
# Validation loss decreased (223.477402 --> 217.400024).  Saving model ...
# [ 46/300] train_loss: 206.412186 valid_loss: 224.196945
# Early Stopping counter: 1 out of 30
# [ 47/300] train_loss: 200.637161 valid_loss: 231.694305
# Early Stopping counter: 2 out of 30
# [ 48/300] train_loss: 201.069809 valid_loss: 219.319473
# Early Stopping counter: 3 out of 30
# [ 49/300] train_loss: 190.027390 valid_loss: 189.805756
# Validation loss decreased (217.400024 --> 189.805756).  Saving model ...
# [ 50/300] train_loss: 170.744095 valid_loss: 183.190033
# Validation loss decreased (189.805756 --> 183.190033).  Saving model ...
# [ 51/300] train_loss: 168.643738 valid_loss: 185.158279
# Early Stopping counter: 1 out of 30
# [ 52/300] train_loss: 156.912262 valid_loss: 189.559814
# Early Stopping counter: 2 out of 30
# [ 53/300] train_loss: 161.395386 valid_loss: 184.468781
# Early Stopping counter: 3 out of 30
# [ 54/300] train_loss: 167.368835 valid_loss: 168.266434
# Validation loss decreased (183.190033 --> 168.266434).  Saving model ...
# [ 55/300] train_loss: 152.950592 valid_loss: 161.797012
# Validation loss decreased (168.266434 --> 161.797012).  Saving model ...
# [ 56/300] train_loss: 143.506882 valid_loss: 158.327148
# Validation loss decreased (161.797012 --> 158.327148).  Saving model ...
# [ 57/300] train_loss: 144.022079 valid_loss: 160.348465
# Early Stopping counter: 1 out of 30
# [ 58/300] train_loss: 135.592346 valid_loss: 153.037964
# Validation loss decreased (158.327148 --> 153.037964).  Saving model ...
# [ 59/300] train_loss: 134.286102 valid_loss: 143.758331
# Validation loss decreased (153.037964 --> 143.758331).  Saving model ...
# [ 60/300] train_loss: 131.629410 valid_loss: 140.762726
# Validation loss decreased (143.758331 --> 140.762726).  Saving model ...
# [ 61/300] train_loss: 134.265030 valid_loss: 139.010208
# Validation loss decreased (140.762726 --> 139.010208).  Saving model ...
# [ 62/300] train_loss: 128.954056 valid_loss: 138.417542
# Validation loss decreased (139.010208 --> 138.417542).  Saving model ...
# [ 63/300] train_loss: 125.364998 valid_loss: 134.166016
# Validation loss decreased (138.417542 --> 134.166016).  Saving model ...
# [ 64/300] train_loss: 122.214691 valid_loss: 132.256546
# Validation loss decreased (134.166016 --> 132.256546).  Saving model ...
# [ 65/300] train_loss: 115.190353 valid_loss: 122.665230
# Validation loss decreased (132.256546 --> 122.665230).  Saving model ...
# [ 66/300] train_loss: 115.674110 valid_loss: 130.236969
# Early Stopping counter: 1 out of 30
# [ 67/300] train_loss: 110.216759 valid_loss: 142.904221
# Early Stopping counter: 2 out of 30
# [ 68/300] train_loss: 109.881721 valid_loss: 148.496338
# Early Stopping counter: 3 out of 30
# [ 69/300] train_loss: 101.288651 valid_loss: 136.800781
# Early Stopping counter: 4 out of 30
# [ 70/300] train_loss: 106.847404 valid_loss: 122.336830
# Validation loss decreased (122.665230 --> 122.336830).  Saving model ...
# [ 71/300] train_loss: 99.348518 valid_loss: 113.795219
# Validation loss decreased (122.336830 --> 113.795219).  Saving model ...
# [ 72/300] train_loss: 101.316574 valid_loss: 112.853355
# Validation loss decreased (113.795219 --> 112.853355).  Saving model ...
# [ 73/300] train_loss: 97.048805 valid_loss: 115.663506
# Early Stopping counter: 1 out of 30
# [ 74/300] train_loss: 93.103455 valid_loss: 119.344635
# Early Stopping counter: 2 out of 30
# [ 75/300] train_loss: 87.256912 valid_loss: 114.875191
# Early Stopping counter: 3 out of 30
# [ 76/300] train_loss: 93.561737 valid_loss: 105.467438
# Validation loss decreased (112.853355 --> 105.467438).  Saving model ...
# [ 77/300] train_loss: 85.046242 valid_loss: 101.221451
# Validation loss decreased (105.467438 --> 101.221451).  Saving model ...
# [ 78/300] train_loss: 85.844345 valid_loss: 110.923294
# Early Stopping counter: 1 out of 30
# [ 79/300] train_loss: 80.575829 valid_loss: 116.864098
# Early Stopping counter: 2 out of 30
# [ 80/300] train_loss: 77.302055 valid_loss: 122.257355
# Early Stopping counter: 3 out of 30
# [ 81/300] train_loss: 76.954514 valid_loss: 118.746323
# Early Stopping counter: 4 out of 30
# [ 82/300] train_loss: 73.874565 valid_loss: 109.928185
# Early Stopping counter: 5 out of 30
# [ 83/300] train_loss: 75.058258 valid_loss: 117.520508
# Early Stopping counter: 6 out of 30
# [ 84/300] train_loss: 75.593369 valid_loss: 106.335434
# Early Stopping counter: 7 out of 30
# [ 85/300] train_loss: 74.471695 valid_loss: 124.569473
# Early Stopping counter: 8 out of 30
# [ 86/300] train_loss: 75.602158 valid_loss: 120.251709
# Early Stopping counter: 9 out of 30
# [ 87/300] train_loss: 80.232407 valid_loss: 113.157906
# Early Stopping counter: 10 out of 30
# [ 88/300] train_loss: 67.213226 valid_loss: 123.313843
# Early Stopping counter: 11 out of 30
# [ 89/300] train_loss: 71.367149 valid_loss: 131.904022
# Early Stopping counter: 12 out of 30
# [ 90/300] train_loss: 91.557831 valid_loss: 121.038261
# Early Stopping counter: 13 out of 30
# [ 91/300] train_loss: 65.389610 valid_loss: 137.295380
# Early Stopping counter: 14 out of 30
# [ 92/300] train_loss: 73.132866 valid_loss: 108.407997
# Early Stopping counter: 15 out of 30
# [ 93/300] train_loss: 64.136803 valid_loss: 105.034119
# Early Stopping counter: 16 out of 30
# [ 94/300] train_loss: 65.999725 valid_loss: 111.235435
# Early Stopping counter: 17 out of 30
# [ 95/300] train_loss: 68.435730 valid_loss: 118.581154
# Early Stopping counter: 18 out of 30
# [ 96/300] train_loss: 58.450436 valid_loss: 123.258354
# Early Stopping counter: 19 out of 30
# [ 97/300] train_loss: 62.444885 valid_loss: 114.810036
# Early Stopping counter: 20 out of 30
# [ 98/300] train_loss: 58.646484 valid_loss: 112.977745
# Early Stopping counter: 21 out of 30
# [ 99/300] train_loss: 61.141380 valid_loss: 107.973892
# Early Stopping counter: 22 out of 30
# [100/300] train_loss: 53.711578 valid_loss: 101.916550
# Early Stopping counter: 23 out of 30
# [101/300] train_loss: 54.385502 valid_loss: 103.638046
# Early Stopping counter: 24 out of 30
# [102/300] train_loss: 56.932789 valid_loss: 109.412041
# Early Stopping counter: 25 out of 30
# [103/300] train_loss: 52.970482 valid_loss: 106.919540
# Early Stopping counter: 26 out of 30
# [104/300] train_loss: 49.359715 valid_loss: 99.037270
# Validation loss decreased (101.221451 --> 99.037270).  Saving model ...
# [105/300] train_loss: 49.709381 valid_loss: 97.277260
# Validation loss decreased (99.037270 --> 97.277260).  Saving model ...
# [106/300] train_loss: 49.713333 valid_loss: 102.591164
# Early Stopping counter: 1 out of 30
# [107/300] train_loss: 47.089890 valid_loss: 102.662460
# Early Stopping counter: 2 out of 30
# [108/300] train_loss: 44.368084 valid_loss: 107.896378
# Early Stopping counter: 3 out of 30
# [109/300] train_loss: 48.371475 valid_loss: 115.050797
# Early Stopping counter: 4 out of 30
# [110/300] train_loss: 46.737286 valid_loss: 118.854225
# Early Stopping counter: 5 out of 30
# [111/300] train_loss: 47.030331 valid_loss: 102.756134
# Early Stopping counter: 6 out of 30
# [112/300] train_loss: 46.166882 valid_loss: 97.722527
# Early Stopping counter: 7 out of 30
# [113/300] train_loss: 48.576321 valid_loss: 101.062065
# Early Stopping counter: 8 out of 30
# [114/300] train_loss: 45.515129 valid_loss: 103.075325
# Early Stopping counter: 9 out of 30
# [115/300] train_loss: 41.323513 valid_loss: 101.675285
# Early Stopping counter: 10 out of 30
# [116/300] train_loss: 41.253868 valid_loss: 97.830704
# Early Stopping counter: 11 out of 30
# [117/300] train_loss: 39.598820 valid_loss: 98.622238
# Early Stopping counter: 12 out of 30
# [118/300] train_loss: 40.270443 valid_loss: 94.991058
# Validation loss decreased (97.277260 --> 94.991058).  Saving model ...
# [119/300] train_loss: 37.518547 valid_loss: 90.203796
# Validation loss decreased (94.991058 --> 90.203796).  Saving model ...
# [120/300] train_loss: 40.842789 valid_loss: 90.400719
# Early Stopping counter: 1 out of 30
# [121/300] train_loss: 39.341019 valid_loss: 95.089981
# Early Stopping counter: 2 out of 30
# [122/300] train_loss: 37.078094 valid_loss: 94.558159
# Early Stopping counter: 3 out of 30
# [123/300] train_loss: 38.258366 valid_loss: 91.867363
# Early Stopping counter: 4 out of 30
# [124/300] train_loss: 39.646038 valid_loss: 92.609642
# Early Stopping counter: 5 out of 30
# [125/300] train_loss: 33.260914 valid_loss: 97.406029
# Early Stopping counter: 6 out of 30
# [126/300] train_loss: 38.229084 valid_loss: 93.035072
# Early Stopping counter: 7 out of 30
# [127/300] train_loss: 36.087101 valid_loss: 88.600464
# Validation loss decreased (90.203796 --> 88.600464).  Saving model ...
# [128/300] train_loss: 32.351288 valid_loss: 87.119957
# Validation loss decreased (88.600464 --> 87.119957).  Saving model ...
# [129/300] train_loss: 34.291077 valid_loss: 91.254128
# Early Stopping counter: 1 out of 30
# [130/300] train_loss: 33.954323 valid_loss: 96.987335
# Early Stopping counter: 2 out of 30
# [131/300] train_loss: 37.966164 valid_loss: 101.425941
# Early Stopping counter: 3 out of 30
# [132/300] train_loss: 33.292393 valid_loss: 98.412537
# Early Stopping counter: 4 out of 30
# [133/300] train_loss: 32.106934 valid_loss: 95.940933
# Early Stopping counter: 5 out of 30
# [134/300] train_loss: 33.892105 valid_loss: 88.145439
# Early Stopping counter: 6 out of 30
# [135/300] train_loss: 35.381905 valid_loss: 86.386391
# Validation loss decreased (87.119957 --> 86.386391).  Saving model ...
# [136/300] train_loss: 33.080872 valid_loss: 90.242638
# Early Stopping counter: 1 out of 30
# [137/300] train_loss: 34.754776 valid_loss: 90.056389
# Early Stopping counter: 2 out of 30
# [138/300] train_loss: 28.536619 valid_loss: 91.320312
# Early Stopping counter: 3 out of 30
# [139/300] train_loss: 32.631123 valid_loss: 86.965347
# Early Stopping counter: 4 out of 30
# [140/300] train_loss: 29.333048 valid_loss: 85.308037
# Validation loss decreased (86.386391 --> 85.308037).  Saving model ...
# [141/300] train_loss: 31.406677 valid_loss: 87.712608
# Early Stopping counter: 1 out of 30
# [142/300] train_loss: 32.073784 valid_loss: 87.735977
# Early Stopping counter: 2 out of 30
# [143/300] train_loss: 30.797852 valid_loss: 93.664650
# Early Stopping counter: 3 out of 30
# [144/300] train_loss: 29.830158 valid_loss: 98.883324
# Early Stopping counter: 4 out of 30
# [145/300] train_loss: 30.783184 valid_loss: 94.263504
# Early Stopping counter: 5 out of 30
# [146/300] train_loss: 32.124599 valid_loss: 88.688667
# Early Stopping counter: 6 out of 30
# [147/300] train_loss: 30.315979 valid_loss: 91.370674
# Early Stopping counter: 7 out of 30
# [148/300] train_loss: 33.644650 valid_loss: 85.573776
# Early Stopping counter: 8 out of 30
# [149/300] train_loss: 29.006527 valid_loss: 84.783707
# Validation loss decreased (85.308037 --> 84.783707).  Saving model ...
# [150/300] train_loss: 33.838024 valid_loss: 87.801857
# Early Stopping counter: 1 out of 30
# [151/300] train_loss: 29.923338 valid_loss: 89.461685
# Early Stopping counter: 2 out of 30
# [152/300] train_loss: 29.408316 valid_loss: 86.983002
# Early Stopping counter: 3 out of 30
# [153/300] train_loss: 30.742733 valid_loss: 85.013657
# Early Stopping counter: 4 out of 30
# [154/300] train_loss: 29.790798 valid_loss: 88.264084
# Early Stopping counter: 5 out of 30
# [155/300] train_loss: 27.525549 valid_loss: 87.522545
# Early Stopping counter: 6 out of 30
# [156/300] train_loss: 27.952017 valid_loss: 88.836105
# Early Stopping counter: 7 out of 30
# [157/300] train_loss: 27.419798 valid_loss: 91.998199
# Early Stopping counter: 8 out of 30
# [158/300] train_loss: 24.718472 valid_loss: 89.795609
# Early Stopping counter: 9 out of 30
# [159/300] train_loss: 28.495592 valid_loss: 85.362488
# Early Stopping counter: 10 out of 30
# [160/300] train_loss: 25.111666 valid_loss: 83.205063
# Validation loss decreased (84.783707 --> 83.205063).  Saving model ...
# [161/300] train_loss: 26.195787 valid_loss: 84.733727
# Early Stopping counter: 1 out of 30
# [162/300] train_loss: 26.793009 valid_loss: 86.037704
# Early Stopping counter: 2 out of 30
# [163/300] train_loss: 25.429819 valid_loss: 82.478554
# Validation loss decreased (83.205063 --> 82.478554).  Saving model ...
# [164/300] train_loss: 25.163301 valid_loss: 80.270790
# Validation loss decreased (82.478554 --> 80.270790).  Saving model ...
# [165/300] train_loss: 25.384209 valid_loss: 78.726418
# Validation loss decreased (80.270790 --> 78.726418).  Saving model ...
# [166/300] train_loss: 27.655010 valid_loss: 79.863106
# Early Stopping counter: 1 out of 30
# [167/300] train_loss: 24.913538 valid_loss: 86.310371
# Early Stopping counter: 2 out of 30
# [168/300] train_loss: 25.862495 valid_loss: 94.664536
# Early Stopping counter: 3 out of 30
# [169/300] train_loss: 25.000988 valid_loss: 90.951874
# Early Stopping counter: 4 out of 30
# [170/300] train_loss: 23.011625 valid_loss: 83.688225
# Early Stopping counter: 5 out of 30
# [171/300] train_loss: 25.777880 valid_loss: 80.963051
# Early Stopping counter: 6 out of 30
# [172/300] train_loss: 24.262718 valid_loss: 82.900978
# Early Stopping counter: 7 out of 30
# [173/300] train_loss: 26.350851 valid_loss: 83.767502
# Early Stopping counter: 8 out of 30
# [174/300] train_loss: 25.156313 valid_loss: 82.768349
# Early Stopping counter: 9 out of 30
# [175/300] train_loss: 24.299818 valid_loss: 82.476318
# Early Stopping counter: 10 out of 30
# [176/300] train_loss: 24.999327 valid_loss: 77.032082
# Validation loss decreased (78.726418 --> 77.032082).  Saving model ...
# [177/300] train_loss: 25.965485 valid_loss: 80.640572
# Early Stopping counter: 1 out of 30
# [178/300] train_loss: 26.374660 valid_loss: 97.651764
# Early Stopping counter: 2 out of 30
# [179/300] train_loss: 30.888178 valid_loss: 91.270561
# Early Stopping counter: 3 out of 30
# [180/300] train_loss: 23.398960 valid_loss: 88.316231
# Early Stopping counter: 4 out of 30
# [181/300] train_loss: 24.035913 valid_loss: 85.694313
# Early Stopping counter: 5 out of 30
# [182/300] train_loss: 23.168039 valid_loss: 81.483437
# Early Stopping counter: 6 out of 30
# [183/300] train_loss: 22.265562 valid_loss: 82.918350
# Early Stopping counter: 7 out of 30
# [184/300] train_loss: 27.081497 valid_loss: 88.489876
# Early Stopping counter: 8 out of 30
# [185/300] train_loss: 23.852816 valid_loss: 92.756157
# Early Stopping counter: 9 out of 30
# [186/300] train_loss: 24.749975 valid_loss: 82.764809
# Early Stopping counter: 10 out of 30
# [187/300] train_loss: 23.862000 valid_loss: 78.581680
# Early Stopping counter: 11 out of 30
# [188/300] train_loss: 25.133659 valid_loss: 80.040909
# Early Stopping counter: 12 out of 30
# [189/300] train_loss: 25.159880 valid_loss: 79.837799
# Early Stopping counter: 13 out of 30
# [190/300] train_loss: 19.975372 valid_loss: 82.368629
# Early Stopping counter: 14 out of 30
# [191/300] train_loss: 21.663656 valid_loss: 92.803337
# Early Stopping counter: 15 out of 30
# [192/300] train_loss: 23.059900 valid_loss: 88.420441
# Early Stopping counter: 16 out of 30
# [193/300] train_loss: 21.369465 valid_loss: 81.911842
# Early Stopping counter: 17 out of 30
# [194/300] train_loss: 21.116047 valid_loss: 76.495361
# Validation loss decreased (77.032082 --> 76.495361).  Saving model ...
# [195/300] train_loss: 21.152679 valid_loss: 77.107552
# Early Stopping counter: 1 out of 30
# [196/300] train_loss: 19.298849 valid_loss: 79.630524
# Early Stopping counter: 2 out of 30
# [197/300] train_loss: 19.958401 valid_loss: 85.144699
# Early Stopping counter: 3 out of 30
# [198/300] train_loss: 22.972178 valid_loss: 85.720322
# Early Stopping counter: 4 out of 30
# [199/300] train_loss: 19.407143 valid_loss: 85.713417
# Early Stopping counter: 5 out of 30
# [200/300] train_loss: 20.167646 valid_loss: 79.053688
# Early Stopping counter: 6 out of 30
# [201/300] train_loss: 19.711365 valid_loss: 77.668823
# Early Stopping counter: 7 out of 30
# [202/300] train_loss: 19.147465 valid_loss: 79.166801
# Early Stopping counter: 8 out of 30
# [203/300] train_loss: 20.530367 valid_loss: 81.912247
# Early Stopping counter: 9 out of 30
# [204/300] train_loss: 19.754900 valid_loss: 81.345802
# Early Stopping counter: 10 out of 30
# [205/300] train_loss: 18.428623 valid_loss: 78.056000
# Early Stopping counter: 11 out of 30
# [206/300] train_loss: 20.578058 valid_loss: 77.303261
# Early Stopping counter: 12 out of 30
# [207/300] train_loss: 20.289242 valid_loss: 78.149788
# Early Stopping counter: 13 out of 30
# [208/300] train_loss: 17.553310 valid_loss: 80.569847
# Early Stopping counter: 14 out of 30
# [209/300] train_loss: 19.301584 valid_loss: 81.680984
# Early Stopping counter: 15 out of 30
# [210/300] train_loss: 20.202721 valid_loss: 82.292740
# Early Stopping counter: 16 out of 30
# [211/300] train_loss: 17.276642 valid_loss: 82.826477
# Early Stopping counter: 17 out of 30
# [212/300] train_loss: 18.096395 valid_loss: 78.899101
# Early Stopping counter: 18 out of 30
# [213/300] train_loss: 18.376034 valid_loss: 77.673462
# Early Stopping counter: 19 out of 30
# [214/300] train_loss: 20.272306 valid_loss: 78.723427
# Early Stopping counter: 20 out of 30
# [215/300] train_loss: 19.314669 valid_loss: 80.250381
# Early Stopping counter: 21 out of 30
# [216/300] train_loss: 16.837942 valid_loss: 79.616318
# Early Stopping counter: 22 out of 30
# [217/300] train_loss: 19.877050 valid_loss: 76.268639
# Validation loss decreased (76.495361 --> 76.268639).  Saving model ...
# [218/300] train_loss: 18.820555 valid_loss: 77.347420
# Early Stopping counter: 1 out of 30
# [219/300] train_loss: 18.692755 valid_loss: 75.748413
# Validation loss decreased (76.268639 --> 75.748413).  Saving model ...
# [220/300] train_loss: 18.672951 valid_loss: 78.551514
# Early Stopping counter: 1 out of 30
# [221/300] train_loss: 18.601376 valid_loss: 85.844101
# Early Stopping counter: 2 out of 30
# [222/300] train_loss: 18.208149 valid_loss: 82.687752
# Early Stopping counter: 3 out of 30
# [223/300] train_loss: 17.065258 valid_loss: 79.641182
# Early Stopping counter: 4 out of 30
# [224/300] train_loss: 22.225189 valid_loss: 76.955559
# Early Stopping counter: 5 out of 30
# [225/300] train_loss: 16.835579 valid_loss: 80.732780
# Early Stopping counter: 6 out of 30
# [226/300] train_loss: 17.191793 valid_loss: 76.915382
# Early Stopping counter: 7 out of 30
# [227/300] train_loss: 16.978022 valid_loss: 76.212799
# Early Stopping counter: 8 out of 30
# [228/300] train_loss: 18.155998 valid_loss: 80.918633
# Early Stopping counter: 9 out of 30
# [229/300] train_loss: 18.268263 valid_loss: 78.917900
# Early Stopping counter: 10 out of 30
# [230/300] train_loss: 19.178289 valid_loss: 79.099831
# Early Stopping counter: 11 out of 30
# [231/300] train_loss: 16.582050 valid_loss: 80.799591
# Early Stopping counter: 12 out of 30
# [232/300] train_loss: 19.615334 valid_loss: 77.447823
# Early Stopping counter: 13 out of 30
# [233/300] train_loss: 17.482758 valid_loss: 79.915527
# Early Stopping counter: 14 out of 30
# [234/300] train_loss: 18.065596 valid_loss: 83.272865
# Early Stopping counter: 15 out of 30
# [235/300] train_loss: 17.189032 valid_loss: 76.908356
# Early Stopping counter: 16 out of 30
# [236/300] train_loss: 18.724184 valid_loss: 76.227043
# Early Stopping counter: 17 out of 30
# [237/300] train_loss: 16.017172 valid_loss: 78.965614
# Early Stopping counter: 18 out of 30
# [238/300] train_loss: 17.303585 valid_loss: 80.450882
# Early Stopping counter: 19 out of 30
# [239/300] train_loss: 17.384565 valid_loss: 80.229416
# Early Stopping counter: 20 out of 30
# [240/300] train_loss: 14.026880 valid_loss: 77.948502
# Early Stopping counter: 21 out of 30
# [241/300] train_loss: 18.064154 valid_loss: 77.874893
# Early Stopping counter: 22 out of 30
# [242/300] train_loss: 16.477095 valid_loss: 76.381454
# Early Stopping counter: 23 out of 30
# [243/300] train_loss: 15.601815 valid_loss: 77.647247
# Early Stopping counter: 24 out of 30
# [244/300] train_loss: 15.220860 valid_loss: 82.882858
# Early Stopping counter: 25 out of 30
# [245/300] train_loss: 16.291510 valid_loss: 81.329552
# Early Stopping counter: 26 out of 30
# [246/300] train_loss: 16.528000 valid_loss: 77.910583
# Early Stopping counter: 27 out of 30
# [247/300] train_loss: 16.644129 valid_loss: 75.529800
# Validation loss decreased (75.748413 --> 75.529800).  Saving model ...
# [248/300] train_loss: 17.055202 valid_loss: 78.767525
# Early Stopping counter: 1 out of 30
# [249/300] train_loss: 14.922545 valid_loss: 77.081711
# Early Stopping counter: 2 out of 30
# [250/300] train_loss: 17.503769 valid_loss: 75.109200
# Validation loss decreased (75.529800 --> 75.109200).  Saving model ...
# [251/300] train_loss: 15.228295 valid_loss: 77.317398
# Early Stopping counter: 1 out of 30
# [252/300] train_loss: 16.858627 valid_loss: 78.954109
# Early Stopping counter: 2 out of 30
# [253/300] train_loss: 13.935887 valid_loss: 80.994537
# Early Stopping counter: 3 out of 30
# [254/300] train_loss: 15.556651 valid_loss: 79.614578
# Early Stopping counter: 4 out of 30
# [255/300] train_loss: 14.667450 valid_loss: 80.200432
# Early Stopping counter: 5 out of 30
# [256/300] train_loss: 14.645535 valid_loss: 76.796303
# Early Stopping counter: 6 out of 30
# [257/300] train_loss: 14.032764 valid_loss: 73.659172
# Validation loss decreased (75.109200 --> 73.659172).  Saving model ...
# [258/300] train_loss: 14.885561 valid_loss: 72.443565
# Validation loss decreased (73.659172 --> 72.443565).  Saving model ...
# [259/300] train_loss: 14.995873 valid_loss: 75.868347
# Early Stopping counter: 1 out of 30
# [260/300] train_loss: 13.630425 valid_loss: 74.017998
# Early Stopping counter: 2 out of 30
# [261/300] train_loss: 14.653772 valid_loss: 73.078865
# Early Stopping counter: 3 out of 30
# [262/300] train_loss: 13.240331 valid_loss: 72.244118
# Validation loss decreased (72.443565 --> 72.244118).  Saving model ...
# [263/300] train_loss: 14.952578 valid_loss: 74.415550
# Early Stopping counter: 1 out of 30
# [264/300] train_loss: 13.467342 valid_loss: 82.453560
# Early Stopping counter: 2 out of 30
# [265/300] train_loss: 15.178772 valid_loss: 75.315117
# Early Stopping counter: 3 out of 30
# [266/300] train_loss: 13.643680 valid_loss: 72.996353
# Early Stopping counter: 4 out of 30
# [267/300] train_loss: 15.071571 valid_loss: 71.907829
# Validation loss decreased (72.244118 --> 71.907829).  Saving model ...
# [268/300] train_loss: 15.672503 valid_loss: 77.656136
# Early Stopping counter: 1 out of 30
# [269/300] train_loss: 15.092610 valid_loss: 80.935875
# Early Stopping counter: 2 out of 30
# [270/300] train_loss: 15.396600 valid_loss: 70.652428
# Validation loss decreased (71.907829 --> 70.652428).  Saving model ...
# [271/300] train_loss: 13.340944 valid_loss: 69.555489
# Validation loss decreased (70.652428 --> 69.555489).  Saving model ...
# [272/300] train_loss: 13.567599 valid_loss: 68.960365
# Validation loss decreased (69.555489 --> 68.960365).  Saving model ...
# [273/300] train_loss: 13.738625 valid_loss: 77.927513
# Early Stopping counter: 1 out of 30
# [274/300] train_loss: 15.041827 valid_loss: 83.877228
# Early Stopping counter: 2 out of 30
# [275/300] train_loss: 15.529728 valid_loss: 74.487648
# Early Stopping counter: 3 out of 30
# [276/300] train_loss: 15.236576 valid_loss: 76.711861
# Early Stopping counter: 4 out of 30
# [277/300] train_loss: 17.181015 valid_loss: 71.881569
# Early Stopping counter: 5 out of 30
# [278/300] train_loss: 14.322896 valid_loss: 77.380470
# Early Stopping counter: 6 out of 30
# [279/300] train_loss: 16.899618 valid_loss: 76.887444
# Early Stopping counter: 7 out of 30
# [280/300] train_loss: 14.398950 valid_loss: 72.717567
# Early Stopping counter: 8 out of 30
# [281/300] train_loss: 13.569976 valid_loss: 73.889709
# Early Stopping counter: 9 out of 30
# [282/300] train_loss: 16.226103 valid_loss: 73.187172
# Early Stopping counter: 10 out of 30
# [283/300] train_loss: 13.278356 valid_loss: 74.968346
# Early Stopping counter: 11 out of 30
# [284/300] train_loss: 13.366997 valid_loss: 75.566605
# Early Stopping counter: 12 out of 30
# [285/300] train_loss: 15.906738 valid_loss: 70.358315
# Early Stopping counter: 13 out of 30
# [286/300] train_loss: 11.430806 valid_loss: 72.543106
# Early Stopping counter: 14 out of 30
# [287/300] train_loss: 13.980243 valid_loss: 72.037262
# Early Stopping counter: 15 out of 30
# [288/300] train_loss: 13.601070 valid_loss: 71.319199
# Early Stopping counter: 16 out of 30
# [289/300] train_loss: 13.071070 valid_loss: 70.344589
# Early Stopping counter: 17 out of 30
# [290/300] train_loss: 14.225698 valid_loss: 71.272301
# Early Stopping counter: 18 out of 30
# [291/300] train_loss: 11.131646 valid_loss: 73.478012
# Early Stopping counter: 19 out of 30
# [292/300] train_loss: 15.481235 valid_loss: 76.265556
# Early Stopping counter: 20 out of 30
# [293/300] train_loss: 11.339372 valid_loss: 77.201027
# Early Stopping counter: 21 out of 30
# [294/300] train_loss: 13.106468 valid_loss: 74.686348
# Early Stopping counter: 22 out of 30
# [295/300] train_loss: 15.122255 valid_loss: 72.113716
# Early Stopping counter: 23 out of 30
# [296/300] train_loss: 11.626860 valid_loss: 78.830215
# Early Stopping counter: 24 out of 30
# [297/300] train_loss: 13.836888 valid_loss: 76.041626
# Early Stopping counter: 25 out of 30
# [298/300] train_loss: 12.849450 valid_loss: 75.134392
# Early Stopping counter: 26 out of 30
# [299/300] train_loss: 16.921047 valid_loss: 71.414307
# Early Stopping counter: 27 out of 30
# [300/300] train_loss: 13.978892 valid_loss: 73.624481
# Early Stopping counter: 28 out of 30

# %% [markdown]
# <STEP 5> 학습 결과 표시, 테스트 파일 각도 예측

# %%
def resultShow():                                                               # 학습 완료후 통계자료를 보여줍니다.
  model = NvidiaModel()                                                         # NvidiaModel 의 Summary를 표시합니다.
  summary(model,(3, 66, 200))

  test_dataset = CustomDataset(x_exam_Image, y_exam_Angle)
  test_loader = DataLoader(test_dataset, batch_size=len(x_exam_Image))

  model = NvidiaModel().to(device)
  model.load_state_dict(torch.load(f'_{project}_model_check.pt'))               # 모델 파일
  model.eval()

  y_pred = []
  y_target = []

  with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)

            output = model(data)

            print('pred', output.to(device).numpy())
            print('target', target.to(device).numpy())

            for output_data, target_data in zip(output.to(device).numpy(), target.to(device).numpy()):
              y_pred.append(output_data)
              y_target.append(target_data)

  mse = mean_squared_error(y_target, y_pred)
  r2s = r2_score(y_target, y_pred)
  #-----------------------------------------------------------------------------
  print('\n표준 편차:', f'{mse:.2}')
  print('회귀 결정 계수:', f'{r2s:.2%}')
  #-----------------------------------------------------------------------------
  fig, axes = plt.subplots(1, len(x_exam_Image), figsize=(30, 2+3))
  xTImg = imgPaths(x_exam_Image)                                                # 파일 이름 앞에 경로(path) 추가
  #print(xTImg)
  #print(x_valid_Image)
  for x, c in enumerate(xTImg):
      axes[x].imshow(Image.open(c))
      t = x_exam_Image[x] +' / E:'+str(int(y_pred[x]))
      axes[x].set_title(t)
      axes[x].xaxis.set_ticks([])
      axes[x].yaxis.set_ticks([])

# if len(x_exam_Image): resultShow()
print("학습 소요 시간:", int(elapsedTime/60), '분', elapsedTime%60, '초' )      # 학습 소요시간 프린트
# Out:
# 학습 소요 시간: 0 분 51 초
